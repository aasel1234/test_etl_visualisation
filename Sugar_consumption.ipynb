# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

csv_file_stats = 'sugar_consumption_stats.csv'

data = pd.read_csv('g_sugar_per_person.csv')

summary_stats = (data.describe()).round(2)
print(summary_stats)

def load_to_csv(summary_stats):
    summary_stats.to_csv(csv_file_stats)
    
load_to_csv(summary_stats)

def visualise_plot(data):
    data_to_plot_small = data[['2012','2013','2014','2015','2016','2017','2018']].head(20)

    fig_small = plt.figure(figsize=(10,7))
    data_to_plot_small.boxplot()
    
    plt.title('Sugar Consumption (g per person) per Day')
    plt.ylabel('Sugar intake (g)')
    plt.xlabel('Year')
    plt.show()
    
    data_to_plot_large = data[['2012','2013','2014','2015','2016','2017','2018']]

    fig_large = plt.figure(figsize=(10,7))
    data_to_plot_large.boxplot()
    
    plt.title('Sugar Consumption (g per person) per Day')
    plt.ylabel('Sugar intake (g)')
    plt.xlabel('Year')
    plt.show()
    
visualise_plot(data)
# Out:
#           1961     1962     1963     1964    1965    1966    1967    1968  \
# count   151.00   151.00   151.00   151.00  151.00  151.00  151.00  151.00
# mean     70.10    71.89    73.13    71.95   72.51   71.72   71.55   71.72
# std      97.62    98.92   117.38    93.02   71.05   55.29   48.62   44.12
# min       0.00     0.00     0.08     0.44    0.82    1.67    2.63    3.01
# 25%      27.40    28.70    28.65    29.70   33.35   32.65   33.85   36.75
# 50%      61.30    65.00    63.80    64.10   69.50   72.20   73.50   72.60
# 75%      95.50    97.30    94.65    98.65   98.00  100.50  102.00  105.50
# max    1140.00  1160.00  1410.00  1080.00  764.00  492.00  350.00  188.00
#
#          1969    1970  ...    2009    2010    2011    2012    2013    2014  \
# count  151.00  151.00  ...  175.00  175.00  174.00  174.00  174.00  172.00
# mean    73.39   74.57  ...   84.18   84.04   83.89   84.26   84.66  105.39
# std     47.61   48.05  ...   42.71   42.29   41.79   41.72   41.47   67.05
# ...
